# %% [markdown]
# <a href="https://colab.research.google.com/github/sjamillah/Air_Quality_Forecasting_Model/blob/main/air_quality_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Beijing PM2.5 Air Pollution Forecasting using LSTM Neural Networks
#
# ### This project applies Recurrent Neural Networks (RNNs) and Long Short-Term Memory
# - ### (LSTM) models to solve a real-world problem: forecasting air pollution levels in Beijing.
# - ### Target: Achieve RMSE < 4000 for PM2.5 concentration predictions using historical air quality and weather data.

# %% [markdown]
# ## 1. ENVIRONMENT SETUP AND LIBRARY IMPORTS
# ### Setting up the deep learning environment for air pollution forecasting
# ### Installing and importing all necessary libraries for RNN/LSTM implementation

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# ### Import essential libraries for data manipulation, visualization, and modeling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError
import matplotlib.dates as mdates

# %% [markdown]
# ## 2. DATA LOADING AND INITIALIZATION
# ### Loading historical Beijing PM2.5 and weather data for time series analysis
# ### Setting up proper datetime indexing for sequential data processing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Time_Series_Forecasting_Assignment 1_Data/train.csv', header=0)
test_df = pd.read_csv('/content/drive/MyDrive/Time_Series_Forecasting_Assignment 1_Data/test.csv', header=0)

# %%
train_df.columns = train_df.columns.str.strip()
test_df.columns = test_df.columns.str.strip()

train_df['datetime'] = pd.to_datetime(train_df['datetime'])
test_df['datetime'] = pd.to_datetime(test_df['datetime'])

train_df.set_index('datetime', inplace=True)
test_df.set_index('datetime', inplace=True)

print(f"Training data shape: {train_df.shape}")
print(f"Testing data shape: {test_df.shape}")
print(f"Training data columns: {train_df.columns.tolist()}")
# Out:
# Training data shape: (30676, 11)
# Testing data shape: (13148, 10)
# Training data columns: ['No', 'DEWP', 'TEMP', 'PRES', 'Iws', 'Is', 'Ir', 'cbwd_NW', 'cbwd_SE', 'cbwd_cv', 'pm2.5']

# %% [markdown]
# ## 3. EXPLORATORY DATA ANALYSIS AND VISUALIZATION

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_df.index, train_df['pm2.5'], color='blue', linewidth=0.8)
plt.xlabel('Datetime')
plt.ylabel('PM2.5 (μg/m³)')
plt.title('PM2.5 Concentration Over Time')
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_df['pm2.5'].dropna(), bins=50, color='green', edgecolor='black', alpha=0.7)
plt.xlabel('PM2.5 Value (μg/m³)')
plt.ylabel('Frequency')
plt.title('Distribution of PM2.5 Values')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(train_df['pm2.5'].dropna(), patch_artist=True)
plt.ylabel('PM2.5 (μg/m³)')
plt.title('PM2.5 Box Plot (Outlier Detection)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = train_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, square=True, fmt='.2f', cbar_kws={'shrink': 0.8})
plt.title('Feature Correlation Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. SEQUENTIAL DATA PREPROCESSING FOR RNN/LSTM
# - ### Cleaning and preparing time series data for recurrent neural network training
# - ### Handling missing values with time-aware interpolation methods

# %%
train_df = train_df.interpolate(method='time')
test_df = test_df.interpolate(method='time')

train_df.fillna(train_df.mean(), inplace=True)
test_df.fillna(test_df.mean(), inplace=True)

print(f"Training data: {train_df.isnull().sum().sum()}")
print(f"Testing data: {test_df.isnull().sum().sum()}")
# Out:
# Training data: 0
# Testing data: 0

# %% [markdown]
# ## 5. TIME SERIES SEQUENCE CREATION FOR LSTM INPUT
# - ### Converting raw data into sequential patterns for LSTM training
# - ### Creating sliding windows to capture temporal dependencies in PM2.5 data

# %%
if 'No' in train_df.columns:
    features = train_df.drop(columns=['pm2.5', 'No'])
else:
    features = train_df.drop(columns=['pm2.5'])

target = train_df['pm2.5']

# %%
lookback = 96

def create_sequences(data, target, lookback):
    """
    Create sequences for time series forecasting
    Args:
        data: DataFrame with features
        target: Series with target values
        lookback: Number of timesteps to look back
    """
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data.iloc[i-lookback:i].values)
        y.append(target.iloc[i])
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(features, target, lookback)

print(f"Features shape: {features.shape}")
print(f"Original training data shape: {train_df.shape}")
print(f"Sequence X_train shape: {X_train.shape}")
print(f"Sequence y_train shape: {y_train.shape}")
# Out:
# Features shape: (30676, 9)
# Original training data shape: (30676, 11)
# Sequence X_train shape: (30580, 96, 9)
# Sequence y_train shape: (30580,)

# %% [markdown]
# ## 6. DATA NORMALIZATION FOR OPTIMAL RNN TRAINING
#
# - ### Scaling features and targets to improve LSTM convergence and stability
# - ### Applying MinMax scaling to ensure all variables are in comparable ranges

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1])
X_train_scaled = scaler_X.fit_transform(X_train_reshaped)
X_train_scaled = X_train_scaled.reshape(X_train.shape)

y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()

# %% [markdown]
# ## 7. TRAINING-VALIDATION SPLIT FOR MODEL EVALUATION
#
# - ### Splitting sequential data while preserving temporal order
# - ### Creating validation set to monitor model performance and prevent overfitting

# %%
X_tr, X_val, y_tr, y_val = train_test_split(
    X_train_scaled, y_train_scaled, test_size=0.2, random_state=42
)

print(f"Training set shape: X={X_tr.shape}, y={y_tr.shape}")
print(f"Validation set shape: X={X_val.shape}, y={y_val.shape}")
# Out:
# Training set shape: X=(24464, 96, 9), y=(24464,)
# Validation set shape: X=(6116, 96, 9), y=(6116,)

# %% [markdown]
# ## 8. DEEP LSTM ARCHITECTURE DESIGN FOR PM2.5 FORECASTING
#
# - ### Building a multi-layer LSTM network optimized for air pollution prediction
# - ### Implementing stacked LSTM layers with regularization to achieve RMSE < 4000

# %%
model = Sequential()

model.add(LSTM(units=128, return_sequences=True, input_shape=(lookback, X_train.shape[2]), kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(LSTM(units=64, return_sequences=True, kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(LSTM(units=32, return_sequences=False, kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1))

optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=[RootMeanSquaredError()])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 96, 128)        │        70,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 96, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 96, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 96, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 96, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,465 (525.25 KB)
#  Trainable params: 134,017 (523.50 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ## 10. LSTM MODEL TRAINING PROCESS
# - ### Training the recurrent neural network on Beijing PM2.5 historical data
# - ### Fine-tuning hyperparameters to achieve target RMSE performance

# %%
history = model.fit(
    X_tr, y_tr,
    epochs=100,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 158s 391ms/step - loss: 0.8627 - root_mean_squared_error: 0.7894 - val_loss: 0.3754 - val_root_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 2/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 199s 383ms/step - loss: 0.4149 - root_mean_squared_error: 0.2578 - val_loss: 0.2673 - val_root_mean_squared_error: 0.0980 - learning_rate: 5.0000e-04
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 193s 360ms/step - loss: 0.2695 - root_mean_squared_error: 0.1377 - val_loss: 0.2043 - val_root_mean_squared_error: 0.0848 - learning_rate: 5.0000e-04
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 139s 362ms/step - loss: 0.1976 - root_mean_squared_error: 0.0981 - val_loss: 0.1638 - val_root_mean_squared_error: 0.0957 - learning_rate: 5.0000e-04
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 142s 362ms/step - loss: 0.1524 - root_mean_squared_error: 0.0874 - val_loss: 0.1228 - val_root_mean_squared_error: 0.0807 - learning_rate: 5.0000e-04
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 154s 393ms/step - loss: 0.1197 - root_mean_squared_error: 0.0816 - val_loss: 0.1057 - val_root_mean_squared_error: 0.0729 - learning_rate: 5.0000e-04
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 192s 367ms/step - loss: 0.0959 - root_mean_squared_error: 0.0769 - val_loss: 0.0833 - val_root_mean_squared_error: 0.0764 - learning_rate: 5.0000e-04
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 144s 373ms/step - loss: 0.0811 - root_mean_squared_error: 0.0761 - val_loss: 0.0734 - val_root_mean_squared_error: 0.0797 - learning_rate: 5.0000e-04
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 139s 363ms/step - loss: 0.0693 - root_mean_squared_error: 0.0726 - val_loss: 0.0690 - val_root_mean_squared_error: 0.0839 - learning_rate: 5.0000e-04
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 152s 390ms/step - loss: 0.0613 - root_mean_squared_error: 0.0721 - val_loss: 0.0576 - val_root_mean_squared_error: 0.0748 - learning_rate: 5.0000e-04
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 192s 365ms/step - loss: 0.0556 - root_mean_squared_error: 0.0699 - val_loss: 0.0834 - val_root_mean_squared_error: 0.1131 - learning_rate: 5.0000e-04
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 148s 386ms/step - loss: 0.0523 - root_mean_squared_error: 0.0713 - val_loss: 0.0606 - val_root_mean_squared_error: 0.0874 - learning_rate: 5.0000e-04
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 204s 391ms/step - loss: 0.0498 - root_mean_squared_error: 0.0695 - val_loss: 0.0724 - val_root_mean_squared_error: 0.1060 - learning_rate: 5.0000e-04
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 390ms/step - loss: 0.0478 - root_mean_squared_error: 0.0693 - val_loss: 0.0531 - val_root_mean_squared_error: 0.0821 - learning_rate: 5.0000e-04
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 152s 395ms/step - loss: 0.0469 - root_mean_squared_error: 0.0695 - val_loss: 0.0588 - val_root_mean_squared_error: 0.0920 - learning_rate: 5.0000e-04
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 189s 362ms/step - loss: 0.0462 - root_mean_squared_error: 0.0680 - val_loss: 0.0564 - val_root_mean_squared_error: 0.0754 - learning_rate: 5.0000e-04
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 150s 383ms/step - loss: 0.0456 - root_mean_squared_error: 0.0680 - val_loss: 0.0524 - val_root_mean_squared_error: 0.0734 - learning_rate: 5.0000e-04
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 209s 402ms/step - loss: 0.0448 - root_mean_squared_error: 0.0676 - val_loss: 0.0412 - val_root_mean_squared_error: 0.0631 - learning_rate: 5.0000e-04
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 141s 368ms/step - loss: 0.0444 - root_mean_squared_error: 0.0660 - val_loss: 0.0435 - val_root_mean_squared_error: 0.0619 - learning_rate: 5.0000e-04
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 143s 370ms/step - loss: 0.0442 - root_mean_squared_error: 0.0668 - val_loss: 0.0446 - val_root_mean_squared_error: 0.0687 - learning_rate: 5.0000e-04
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 142s 368ms/step - loss: 0.0447 - root_mean_squared_error: 0.0676 - val_loss: 0.0477 - val_root_mean_squared_error: 0.0744 - learning_rate: 5.0000e-04
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 140s 362ms/step - loss: 0.0438 - root_mean_squared_error: 0.0659 - val_loss: 0.0463 - val_root_mean_squared_error: 0.0731 - learning_rate: 5.0000e-04
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0430 - root_mean_squared_error: 0.0641
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 152s 389ms/step - loss: 0.0430 - root_mean_squared_error: 0.0641 - val_loss: 0.0590 - val_root_mean_squared_error: 0.0872 - learning_rate: 5.0000e-04
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 205s 396ms/step - loss: 0.0432 - root_mean_squared_error: 0.0658 - val_loss: 0.0400 - val_root_mean_squared_error: 0.0639 - learning_rate: 2.5000e-04
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 199s 389ms/step - loss: 0.0422 - root_mean_squared_error: 0.0626 - val_loss: 0.0408 - val_root_mean_squared_error: 0.0634 - learning_rate: 2.5000e-04
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 151s 393ms/step - loss: 0.0419 - root_mean_squared_error: 0.0631 - val_loss: 0.0382 - val_root_mean_squared_error: 0.0569 - learning_rate: 2.5000e-04
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 190s 363ms/step - loss: 0.0412 - root_mean_squared_error: 0.0626 - val_loss: 0.0500 - val_root_mean_squared_error: 0.0781 - learning_rate: 2.5000e-04
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 152s 388ms/step - loss: 0.0408 - root_mean_squared_error: 0.0615 - val_loss: 0.0455 - val_root_mean_squared_error: 0.0663 - learning_rate: 2.5000e-04
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 205s 398ms/step - loss: 0.0408 - root_mean_squared_error: 0.0623 - val_loss: 0.0499 - val_root_mean_squared_error: 0.0815 - learning_rate: 2.5000e-04
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 187s 358ms/step - loss: 0.0420 - root_mean_squared_error: 0.0638 - val_loss: 0.0421 - val_root_mean_squared_error: 0.0615 - learning_rate: 2.5000e-04
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0405 - root_mean_squared_error: 0.0613
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 144s 363ms/step - loss: 0.0405 - root_mean_squared_error: 0.0613 - val_loss: 0.0412 - val_root_mean_squared_error: 0.0636 - learning_rate: 2.5000e-04
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 151s 387ms/step - loss: 0.0406 - root_mean_squared_error: 0.0622 - val_loss: 0.0456 - val_root_mean_squared_error: 0.0670 - learning_rate: 1.2500e-04
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 147s 384ms/step - loss: 0.0392 - root_mean_squared_error: 0.0594 - val_loss: 0.0368 - val_root_mean_squared_error: 0.0549 - learning_rate: 1.2500e-04
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 204s 390ms/step - loss: 0.0393 - root_mean_squared_error: 0.0595 - val_loss: 0.0363 - val_root_mean_squared_error: 0.0542 - learning_rate: 1.2500e-04
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 200s 384ms/step - loss: 0.0399 - root_mean_squared_error: 0.0610 - val_loss: 0.0463 - val_root_mean_squared_error: 0.0673 - learning_rate: 1.2500e-04
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 151s 394ms/step - loss: 0.0387 - root_mean_squared_error: 0.0578 - val_loss: 0.0395 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.2500e-04
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 388ms/step - loss: 0.0387 - root_mean_squared_error: 0.0583 - val_loss: 0.0372 - val_root_mean_squared_error: 0.0553 - learning_rate: 1.2500e-04
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 194s 367ms/step - loss: 0.0390 - root_mean_squared_error: 0.0592 - val_loss: 0.0416 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.2500e-04
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 0.0390 - root_mean_squared_error: 0.0586
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 150s 391ms/step - loss: 0.0390 - root_mean_squared_error: 0.0586 - val_loss: 0.0408 - val_root_mean_squared_error: 0.0628 - learning_rate: 1.2500e-04
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 190s 361ms/step - loss: 0.0387 - root_mean_squared_error: 0.0596 - val_loss: 0.0421 - val_root_mean_squared_error: 0.0649 - learning_rate: 6.2500e-05
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 390ms/step - loss: 0.0379 - root_mean_squared_error: 0.0568 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0526 - learning_rate: 6.2500e-05
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 207s 403ms/step - loss: 0.0377 - root_mean_squared_error: 0.0561 - val_loss: 0.0356 - val_root_mean_squared_error: 0.0542 - learning_rate: 6.2500e-05
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 188s 365ms/step - loss: 0.0380 - root_mean_squared_error: 0.0570 - val_loss: 0.0359 - val_root_mean_squared_error: 0.0546 - learning_rate: 6.2500e-05
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 145s 371ms/step - loss: 0.0377 - root_mean_squared_error: 0.0572 - val_loss: 0.0389 - val_root_mean_squared_error: 0.0584 - learning_rate: 6.2500e-05
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 199s 365ms/step - loss: 0.0382 - root_mean_squared_error: 0.0580 - val_loss: 0.0364 - val_root_mean_squared_error: 0.0545 - learning_rate: 6.2500e-05
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 142s 364ms/step - loss: 0.0379 - root_mean_squared_error: 0.0577 - val_loss: 0.0342 - val_root_mean_squared_error: 0.0514 - learning_rate: 6.2500e-05
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 140s 359ms/step - loss: 0.0372 - root_mean_squared_error: 0.0561 - val_loss: 0.0373 - val_root_mean_squared_error: 0.0569 - learning_rate: 6.2500e-05
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 152s 385ms/step - loss: 0.0380 - root_mean_squared_error: 0.0580 - val_loss: 0.0382 - val_root_mean_squared_error: 0.0559 - learning_rate: 6.2500e-05
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 192s 358ms/step - loss: 0.0379 - root_mean_squared_error: 0.0575 - val_loss: 0.0366 - val_root_mean_squared_error: 0.0570 - learning_rate: 6.2500e-05
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 148s 387ms/step - loss: 0.0366 - root_mean_squared_error: 0.0544 - val_loss: 0.0426 - val_root_mean_squared_error: 0.0676 - learning_rate: 6.2500e-05
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 0.0378 - root_mean_squared_error: 0.0581
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 201s 384ms/step - loss: 0.0378 - root_mean_squared_error: 0.0581 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0530 - learning_rate: 6.2500e-05
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 192s 358ms/step - loss: 0.0372 - root_mean_squared_error: 0.0563 - val_loss: 0.0332 - val_root_mean_squared_error: 0.0506 - learning_rate: 3.1250e-05
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 377ms/step - loss: 0.0373 - root_mean_squared_error: 0.0569 - val_loss: 0.0364 - val_root_mean_squared_error: 0.0561 - learning_rate: 3.1250e-05
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 140s 365ms/step - loss: 0.0373 - root_mean_squared_error: 0.0565 - val_loss: 0.0346 - val_root_mean_squared_error: 0.0535 - learning_rate: 3.1250e-05
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 151s 388ms/step - loss: 0.0369 - root_mean_squared_error: 0.0560 - val_loss: 0.0357 - val_root_mean_squared_error: 0.0546 - learning_rate: 3.1250e-05
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 205s 397ms/step - loss: 0.0376 - root_mean_squared_error: 0.0567 - val_loss: 0.0342 - val_root_mean_squared_error: 0.0513 - learning_rate: 3.1250e-05
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 0.0368 - root_mean_squared_error: 0.0553
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 191s 368ms/step - loss: 0.0368 - root_mean_squared_error: 0.0553 - val_loss: 0.0343 - val_root_mean_squared_error: 0.0522 - learning_rate: 3.1250e-05
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 386ms/step - loss: 0.0365 - root_mean_squared_error: 0.0550 - val_loss: 0.0325 - val_root_mean_squared_error: 0.0495 - learning_rate: 1.5625e-05
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 197s 373ms/step - loss: 0.0366 - root_mean_squared_error: 0.0554 - val_loss: 0.0335 - val_root_mean_squared_error: 0.0510 - learning_rate: 1.5625e-05
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 209s 392ms/step - loss: 0.0370 - root_mean_squared_error: 0.0568 - val_loss: 0.0324 - val_root_mean_squared_error: 0.0492 - learning_rate: 1.5625e-05
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 202s 392ms/step - loss: 0.0369 - root_mean_squared_error: 0.0567 - val_loss: 0.0335 - val_root_mean_squared_error: 0.0511 - learning_rate: 1.5625e-05
# Epoch 62/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 138s 360ms/step - loss: 0.0365 - root_mean_squared_error: 0.0546 - val_loss: 0.0325 - val_root_mean_squared_error: 0.0496 - learning_rate: 1.5625e-05
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - loss: 0.0371 - root_mean_squared_error: 0.0573
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 153s 390ms/step - loss: 0.0371 - root_mean_squared_error: 0.0573 - val_loss: 0.0336 - val_root_mean_squared_error: 0.0514 - learning_rate: 1.5625e-05
# Epoch 64/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 197s 377ms/step - loss: 0.0364 - root_mean_squared_error: 0.0545 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0489 - learning_rate: 7.8125e-06
# Epoch 65/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 196s 361ms/step - loss: 0.0367 - root_mean_squared_error: 0.0547 - val_loss: 0.0327 - val_root_mean_squared_error: 0.0500 - learning_rate: 7.8125e-06
# Epoch 66/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 390ms/step - loss: 0.0368 - root_mean_squared_error: 0.0563 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0493 - learning_rate: 7.8125e-06
# Epoch 67/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 204s 396ms/step - loss: 0.0359 - root_mean_squared_error: 0.0546 - val_loss: 0.0321 - val_root_mean_squared_error: 0.0488 - learning_rate: 7.8125e-06
# Epoch 68/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 137s 359ms/step - loss: 0.0365 - root_mean_squared_error: 0.0551 - val_loss: 0.0329 - val_root_mean_squared_error: 0.0497 - learning_rate: 7.8125e-06
# Epoch 69/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.0363 - root_mean_squared_error: 0.0553
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 149s 376ms/step - loss: 0.0363 - root_mean_squared_error: 0.0553 - val_loss: 0.0326 - val_root_mean_squared_error: 0.0496 - learning_rate: 7.8125e-06
# Epoch 70/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 205s 384ms/step - loss: 0.0364 - root_mean_squared_error: 0.0553 - val_loss: 0.0318 - val_root_mean_squared_error: 0.0486 - learning_rate: 3.9063e-06
# Epoch 71/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 201s 380ms/step - loss: 0.0362 - root_mean_squared_error: 0.0550 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0488 - learning_rate: 3.9063e-06
# Epoch 72/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 210s 402ms/step - loss: 0.0363 - root_mean_squared_error: 0.0550 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0491 - learning_rate: 3.9063e-06
# Epoch 73/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 144s 377ms/step - loss: 0.0360 - root_mean_squared_error: 0.0551 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0489 - learning_rate: 3.9063e-06
# Epoch 74/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 150s 393ms/step - loss: 0.0362 - root_mean_squared_error: 0.0550 - val_loss: 0.0321 - val_root_mean_squared_error: 0.0492 - learning_rate: 3.9063e-06
# Epoch 75/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.0362 - root_mean_squared_error: 0.0554
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 195s 374ms/step - loss: 0.0362 - root_mean_squared_error: 0.0554 - val_loss: 0.0321 - val_root_mean_squared_error: 0.0489 - learning_rate: 3.9063e-06
# Epoch 76/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 145s 379ms/step - loss: 0.0365 - root_mean_squared_error: 0.0551 - val_loss: 0.0319 - val_root_mean_squared_error: 0.0487 - learning_rate: 1.9531e-06
# Epoch 77/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 200s 374ms/step - loss: 0.0365 - root_mean_squared_error: 0.0560 - val_loss: 0.0319 - val_root_mean_squared_error: 0.0489 - learning_rate: 1.9531e-06
# Epoch 78/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 201s 371ms/step - loss: 0.0360 - root_mean_squared_error: 0.0539 - val_loss: 0.0318 - val_root_mean_squared_error: 0.0484 - learning_rate: 1.9531e-06
# Epoch 79/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 138s 359ms/step - loss: 0.0363 - root_mean_squared_error: 0.0540 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0488 - learning_rate: 1.9531e-06
# Epoch 80/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 0.0367 - root_mean_squared_error: 0.0561
# Epoch 80: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 139s 364ms/step - loss: 0.0367 - root_mean_squared_error: 0.0561 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0489 - learning_rate: 1.9531e-06

# %% [markdown]
# ## 11. MODEL PERFORMANCE EVALUATION AND VALIDATION
# - ### Assessing LSTM prediction accuracy using RMSE, MAE, and R² metrics
# - ### Validating model performance against the target RMSE < 4000 threshold

# %%
y_pred = model.predict(X_val)
y_pred = scaler_y.inverse_transform(y_pred)
y_val_inverse = scaler_y.inverse_transform(y_val.reshape(-1, 1))
val_rmse = np.sqrt(mean_squared_error(y_val_inverse, y_pred))

print("Validation RMSE:", val_rmse)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step
# Validation RMSE: 48.35024857483464

# %%
train_predictions = model.predict(X_tr)
train_predictions = scaler_y.inverse_transform(train_predictions)
train_loss = np.mean((scaler_y.inverse_transform(y_tr.reshape(-1, 1)).flatten() - train_predictions.flatten())**2)
train_rmse = np.sqrt(train_loss)

print(f'Training MSE: {train_loss:.4f}')
print(f'Training RMSE: {train_rmse:.4f}')
# Out:
# 765/765 ━━━━━━━━━━━━━━━━━━━━ 59s 77ms/step
# Training MSE: 2498.3689
# Training RMSE: 49.9837

# %% [markdown]
# ## 12. TRAINING ANALYSIS AND PERFORMANCE VISUALIZATION

# %%
train_loss_scaled = history.history['loss'][-1]
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss (scaled)', color='blue')
plt.axhline(y=train_loss_scaled, color='red', linestyle='--', label='Final Training Loss (scaled)')
plt.title('Loss on Training Data (Scaled)')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## 13. TEST DATA SEQUENCE PREPARATION

# %%
print("Test dataframe shape:", test_df.shape)

if 'No' in test_df.columns:
    X_test_features = test_df.drop(['No'], axis=1)
else:
    X_test_features = test_df.copy()
# Out:
# Test dataframe shape: (13148, 10)

# %%
padding = pd.DataFrame([X_test_features.iloc[0].values] * (lookback - 1), columns=X_test_features.columns)
X_test_features_padded = pd.concat([padding, X_test_features], ignore_index=True)

# %%
X_test = []
for i in range(len(X_test_features_padded) - lookback + 1):
    X_test.append(X_test_features_padded.iloc[i:i + lookback].values)

X_test = np.array(X_test)
print(f"Final X_test shape: {X_test.shape}")
# Out:
# Final X_test shape: (13148, 96, 9)

# %%
X_test_reshaped = X_test.reshape(-1, X_test.shape[-1])
X_test_scaled = scaler_X.transform(X_test_reshaped)
X_test_scaled = X_test_scaled.reshape(X_test.shape)

# %% [markdown]
# ## 14. FINAL PM2.5 PREDICTIONS AND COMPETITION SUBMISSION

# %%
predictions_scaled = model.predict(X_test_scaled)
predictions = scaler_y.inverse_transform(predictions_scaled)

predictions = np.nan_to_num(predictions)
predictions = np.round(predictions).astype(int)
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 30s 72ms/step

# %%
submission_indices = test_df.index[:len(predictions)]

submission = pd.DataFrame({
    'row ID': pd.to_datetime(submission_indices).strftime('%Y-%m-%d %-H:%M:%S'),
    'pm2.5': predictions.flatten()
})

submission = submission.sort_values(by='row ID')

submission.to_csv('/content/drive/MyDrive/Kaggle_competition_ML/air_quality_forcasting/subm_fixed.csv', index=False)
